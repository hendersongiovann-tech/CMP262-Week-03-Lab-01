# %% [markdown]
# Creating and Accessing a list

# %%
courses = ["Algebra", "Biology", "Computer Science", "English", "History"]

print(courses)
print(courses[0])
print(courses[2])
print(courses[4])
print(len(courses))

print(courses[:3])
# Out:
# ['Algebra', 'Biology', 'Computer Science', 'English', 'History']
# Algebra
# Computer Science
# History
# 5
# ['Algebra', 'Biology', 'Computer Science']

# %% [markdown]
# modifying a list

# %%
favorite_foods = ["Spaghetti", "Pizza", "cheeseburger", "Fried Chicken", "Ice Cream"]

print(favorite_foods)

favorite_foods[4] = "Cheesecake"
favorite_foods.append("Meatloaf")
favorite_foods.remove("Pizza")

print(favorite_foods)
# Out:
# ['Spaghetti', 'Pizza', 'cheeseburger', 'Fried Chicken', 'Ice Cream']
# ['Spaghetti', 'cheeseburger', 'Fried Chicken', 'Cheesecake', 'Meatloaf']

# %% [markdown]
# Working with Numbers

# %%
scores = [14, 20, 35, 17, 40, 31]

print(scores)
print(max(scores))
print(min(scores))
print(sum(scores))
print(len(scores))

print(sum(scores) / len(scores))
# Out:
# [14, 20, 35, 17, 40, 31]
# 40
# 14
# 157
# 6
# 26.166666666666668

# %% [markdown]
# Looping Through a List

# %%
cities = ["New York", "Los Angelos", "Houston", "Newark", "Miami"]

for city in cities:
    print(city)
# Out:
# New York
# Los Angelos
# Houston
# Newark
# Miami
